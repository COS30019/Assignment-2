# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import networkx as nx
import matplotlib.pyplot as plt

# %%
import pandas as pd
import folium

# Load new dataset
df = pd.read_csv('/Users/mouyly/Downloads/jupiter_notebook/latlong_map.csv')  # updated path to new file
print("Total rows:", len(df))
print("Unique Site IDs:", df['Site ID'].nunique())

# Check how many unique lat/lon pairs
print("Unique lat/lon positions:", df[['Lat', 'Long']].drop_duplicates().shape[0])

# Prepare unique site data
site_data = df[['Site ID', 'Lat', 'Long']].drop_duplicates()

# Define edge list (connections between Site IDs)
edges = [
    (2000, 3682),
    (2000, 4043),
    (4043, 3120),
    (4057, 3180),
    (3180, 4051),
    (4051, 4032),
    (4032, 4321),
    (4321, 2820),
    (2820, 3662),
    (3662, 4262),
    (4262, 4263),
    (4263, 3002),
    (3002, 3662),
    (3662, 4335),
    (4335, 4324),
    (4335, 4321),
    (3120, 3127),
    (3127, 4057),
    (4057, 3180),
    (4051, 2827),
    (4051, 2825),
    (4266, 3120),
    (4324, 2200),
    (3662, 4335),
    (4335, 4321),
]

# Center the map around Boroondara (adjust if needed)
m = folium.Map(
    location=[-37.82, 145.06],
    zoom_start=13,
    tiles='cartodbpositron'
)

# Collect only nodes that are in edge list
connected_nodes = set()
for a, b in edges:
    connected_nodes.add(a)
    connected_nodes.add(b)

# Plot site markers in blue
for _, row in site_data[site_data['Site ID'].isin(connected_nodes)].iterrows():
    folium.CircleMarker(
        location=[row['Lat'], row['Long']],
        radius=5,
        color='blue',
        fill=True,
        fill_opacity=0.9,
        popup=f"Site ID: {row['Site ID']}"
    ).add_to(m)

# Draw green edges between connected site pairs
for a, b in edges:
    try:
        point_a = site_data[site_data['Site ID'] == a].iloc[0]
        point_b = site_data[site_data['Site ID'] == b].iloc[0]

        folium.PolyLine(
            locations=[
                [point_a['Lat'], point_a['Long']],
                [point_b['Lat'], point_b['Long']]
            ],
            color='green',
            weight=3,
            opacity=0.8
        ).add_to(m)
    except IndexError:
        print(f"⚠️ Skipping edge ({a}, {b}) — Site ID not found in latlong_map.csv")

# Save to HTML
m.save("manual_graph_map.html")
print("✅ Map saved as manual_graph_map.html — open it in your browser!")
# Out:
# Total rows: 42
# Unique Site IDs: 40
# Unique lat/lon positions: 41
# ✅ Map saved as manual_graph_map.html — open it in your browser!

# %%
from IPython.display import display

display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e780ad93b23689656c1b0a06cbf7c44e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e780ad93b23689656c1b0a06cbf7c44e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e780ad93b23689656c1b0a06cbf7c44e = L.map(
#                 &quot;map_e780ad93b23689656c1b0a06cbf7c44e&quot;,
#                 {
#                     center: [-37.82, 145.06],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4e09aa3ba16332fcdd12c8d24a4cf1a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4e09aa3ba16332fcdd12c8d24a4cf1a.addTo(map_e780ad93b23689656c1b0a06cbf7c44e);
#
#
#             var circle_marker_77f107a79869216938eda9d99353fbf6 = L.circleMarker(
#                 [-37.850389, 145.095628],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e780ad93b23689656c1b0a06cbf7c44e);
#
#
#         var popup_7081727264a7a9a3e91ec3f698d553bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7064ba52e606a5a1d886518a1ed7df7 = $(`&lt;div id=&quot;html_b7064ba52e606a5a1d886518a1ed7df7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site ID: 2000.0&lt;/div&gt;`)[0];
#                 popup_7081727264a7a9a3e91ec3f698d553bf.setContent(html_b7064ba52e606a5a1d886518a1ed7df7);
#
#
#
#         circle_marker_77f107a79869216938eda9d99353fbf6.bindPopup(popup_7081727264a7a9a3e91ec3f698d553bf)
#         ;
#
#
#
#
#             var circle_marker_7236eef82c608b9593fe9ae633067468 = L.circleMarker(
#                 [-37.815016, 145.099383],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e780ad93b23689656c1b0a06cbf7c44e);
#
#
#         var popup_a352d6be2d0ce14ba711918001032c8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f78df90c7470b4ab016fd42cc8fd650 = $(`&lt;div id=&quot;html_4f78df90c7470b4ab016fd42cc8fd650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site ID: 2200.0&lt;/div&gt;`)[0];
#                 popup_a352d6be2d0ce14ba711918001032c8d.setContent(html_4f78df90c7470b4ab016fd42cc8fd650);
#
#
#
#         circle_marker_7236eef82c608b9593fe9ae633067468.bindPopup(popup_a352d6be2d0ce14ba711918001032c8d)
#         ;
#
#
#
#
#             var circle_marker_1bf451d3ebd45d1ee88829394660ccaf = L.circleMarker(
#                 [-37.792917, 145.031463],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e780ad93b23689656c1b0a06cbf7c44e);
#
#
#         var popup_6bad5a9d94f7c530184ac694d3dd3a5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3678722865a0e30cbf812b111301edf1 = $(`&lt;div id=&quot;html_3678722865a0e30cbf812b111301edf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Site ID: 2820.0&lt;/div&gt;`)[0];
#                 popup_6bad5a9d94f7c530184ac694d3dd3a5b.setContent(html_3678722865a0e30cbf812b111301edf1);
#
#
#
#         circle_marker_1bf451d3ebd45d1ee88829394660ccaf.bindPopup(popup_6bad5a9d94f7c530184ac69
